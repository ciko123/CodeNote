# %% [markdown]
# ### StrOutputParser

# %%
import dotenv
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

dotenv.load_dotenv()

# 1.编排提示模板
prompt = ChatPromptTemplate.from_template("{query}")

# 2.构建大语言模型
llm = ChatOpenAI(
        model="gpt-4o",  # 使用 GPT-4o 模型进行测试
        temperature=0.1,
        max_tokens=100
    )

# 3.创建字符串输出解析器
parser = StrOutputParser()

# 4.调用大语言模型生成结果并解析
content = parser.invoke(llm.invoke(prompt.invoke({"query": "你好，你是?"})))

print(content)
# Out:
# c:\ProgramData\miniconda3\envs\llmops\lib\site-packages\langsmith\client.py:297: LangSmithMissingAPIKeyWarning: API key must be provided when using hosted LangSmith API
#   warnings.warn(
# Failed to multipart ingest runs: langsmith.utils.LangSmithAuthError: Authentication failed for https://api.smith.langchain.com/runs/multipart. HTTPError('401 Client Error: Unauthorized for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Unauthorized"}\n')trace=019af471-a6d4-7493-aa99-9676abab4a16,id=019af471-a6d4-7493-aa99-9676abab4a16; trace=019af471-a723-71a0-8e7e-2818c63e136f,id=019af471-a723-71a0-8e7e-2818c63e136f
# 你好！我是一个人工智能助手，可以回答问题、提供信息或帮助解决问题。有什么可以帮忙的吗？
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithAuthError: Authentication failed for https://api.smith.langchain.com/runs/multipart. HTTPError('401 Client Error: Unauthorized for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Unauthorized"}\n')trace=019af471-a723-71a0-8e7e-2818c63e136f,id=019af471-a723-71a0-8e7e-2818c63e136f; trace=019af471-c321-7da1-8ba3-bc5b7711af8c,id=019af471-c321-7da1-8ba3-bc5b7711af8c; trace=019af471-c321-7da1-8ba3-bc5b7711af8c,id=019af471-c321-7da1-8ba3-bc5b7711af8c

# %% [markdown]
# ### JsonOutputParser
#
# 在LangChain v0.2+中，pydantic_v1已被移除，使用pydantic v2语法。

# %%
from pydantic import BaseModel, Field
from langchain_core.output_parsers import JsonOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
import dotenv

dotenv.load_dotenv()


# 1.创建一个json数据结构，用于告诉大语言模型这个json长什么样子
class Joke(BaseModel):
    # 冷笑话
    joke: str = Field(description="回答用户的冷笑话")
    # 冷笑话的笑点
    punchline: str = Field(description="这个冷笑话的笑点")


parser = JsonOutputParser(pydantic_object=Joke)

# 2.构建一个提示模板
prompt = ChatPromptTemplate.from_template("请根据用户的提问进行回答。\n{format_instructions}\n{query}").partial(
    format_instructions=parser.get_format_instructions())

# 3.构建一个大语言模型
llm = ChatOpenAI(
        model="gpt-4o",  # 使用 GPT-4o 模型进行测试
        temperature=0.1,
        max_tokens=100
    )

# 4.传递提示并进行解析
joke = parser.invoke(llm.invoke(prompt.invoke({"query": "请讲一个关于程序员的冷笑话"})))

print(type(joke))
print(joke.get("punchline"))
print(joke)
# Out:
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithAuthError: Authentication failed for https://api.smith.langchain.com/runs/multipart. HTTPError('401 Client Error: Unauthorized for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Unauthorized"}\n')trace=019af475-3651-7401-bb55-2794ebe2bcf6,id=019af475-3651-7401-bb55-2794ebe2bcf6; trace=019af475-3651-7401-bb55-2794ebe2bcf6,id=019af475-3651-7401-bb55-2794ebe2bcf6; trace=019af475-3656-7a73-b91b-319d129b880c,id=019af475-3656-7a73-b91b-319d129b880c
# <class 'dict'>
# 因为他们觉得黑色键盘能隐藏他们的代码错误。
# {'joke': '为什么程序员喜欢用黑色的键盘？', 'punchline': '因为他们觉得黑色键盘能隐藏他们的代码错误。'}
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithAuthError: Authentication failed for https://api.smith.langchain.com/runs/multipart. HTTPError('401 Client Error: Unauthorized for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Unauthorized"}\n')trace=019af475-3656-7a73-b91b-319d129b880c,id=019af475-3656-7a73-b91b-319d129b880c; trace=019af475-51da-7183-9c72-753300f2107a,id=019af475-51da-7183-9c72-753300f2107a; trace=019af475-51da-7183-9c72-753300f2107a,id=019af475-51da-7183-9c72-753300f2107a
