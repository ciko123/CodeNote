# %%
# %run "contant.py"
# Out:
# 已加载全局配置
#
# 🎯 模型常量:
#   OPENAI_MODEL, open_model
#
# 🎨 打印方法:
#   pretty_print, print_json
#   print_agent

# %%
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import TextLoader

# 步骤1：加载文本文件
loader = TextLoader("./test/file/sample.txt")
docs = loader.load()

# 步骤2：分割文本为更小的块
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=100,           # 每块500个字符
    chunk_overlap=5,         # 块之间重叠50个字符
    separators=["\n\n", "\n", " ", ""]  # 分割符优先级
)
chunks = text_splitter.split_documents(docs)

print_json(chunks)
# Out:
# [
#   {
#     "id": null,
#     "metadata": {
#       "source": "./test/file/sample.txt"
#     },
#     "page_content": "LangChain简介\n\nLangChain是一个强大的框架，用于开发由大型语言模型(LLM)驱动的应用程序。\n它提供了一套工具和库，使开发人员能够轻松构建复杂的AI应用。",
#     "type": "Document"
#   },
#   {
#     "id": null,
#     "metadata": {
#       "source": "./test/file/sample.txt"
#     },
#     "page_content": "主要特性：\n1. 文档加载器 - 支持多种数据源\n2. 文本分割器 - 将长文本分成小块\n3. 向量存储 - 进行语义搜索\n4. 链 - 组合多个组件\n5. 代理 - 实现智能决策",
#     "type": "Document"
#   },
#   {
#     "id": null,
#     "metadata": {
#       "source": "./test/file/sample.txt"
#     },
#     "page_content": "LangChain的应用场景包括：\n- 问答系统\n- 文档分析\n- 检索增强生成(RAG)\n- 聊天机器人",
#     "type": "Document"
#   }
# ]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
