# %%
# %run "contant.py"
# Out:
# 已加载全局配置
#
# 🎯 模型常量:
#   OPENAI_MODEL, open_model
#
# 🎨 打印方法:
#   pretty_print, print_json
#   print_agent

# %% [markdown]
# ## 检查点

# %% [markdown]
# 跨会话恢复 - 在不同的对话中恢复之前的状态
#
# 时间旅行 - 重放历史执行步骤进行调试
#
# 人工循环 - 实现中断、审批等工作流

# %% [markdown]
# ## 消息历史

# %% [markdown]
# ## Store 系统
