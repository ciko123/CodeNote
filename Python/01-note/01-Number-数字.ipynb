# %% [markdown]
# ### 数字类型
#
# - int (整数), 如 1, 只有一种整数类型 int，表示为长整型
# - float (浮点数), 如 1.23、3E-2
# - complex (复数) - 复数由实部和虚部组成，形式为 a + bj，其中 a 是实部，b 是虚部，j 表示虚数单位。如 1 + 2j、 1.1 + 2.2j
#
# ---
# - 没有 python2 中的 Long。

# %%
num_int = 1         # int
num_float = 1.0     # float

complex_num = 3 + 4j  # 复数
print(f"复数: {complex_num}")
print(f"复数实部: {complex_num.real}")
print(f"复数虚部: {complex_num.imag}")

# %%
count = 0
count += 1
# count++ # 不支持

print(count)
# Out:
# 1

# %%
number = 0b10   # 二进制
number = 0o37   # 八进制
number = 0xA0F  # 十六进制

# %% [markdown]
# ### 进制之间的转换

# %%
bin_num = 0b1010   # 二进制

print(int(bin_num))  # 输出：10（十进制）
print(oct(bin_num))  # 输出：0o12（八进制）
print(hex(bin_num))  # 输出：0xa（十六进制）

oct_num = 0o37   # 八进制number = 0o37   # 八进制

print(int(oct_num))  # 输出：10（十进制）
print(bin(oct_num))  # 输出：0b11111（二进制）
print(hex(oct_num))  # 输出：0x1f（十六进制

hex_num = 0x0A  # 十六进制
print(int(hex_num))  # 输出：2575（十进制）
print(bin(hex_num))  # 输出：0b101000001111（二进制）
print(oct(hex_num))  # 输出：0o12017（八进制）
# Out:
# 10
# 0o12
# 0xa
# 31
# 0b11111
# 0x1f
# 10
# 0b1010
# 0o12

# %% [markdown]
# ### 数字方法

# %%
# 数学函数
print(f"\n📝 5. 基础数学函数:")
import math
num = 16
print(f"绝对值: abs(-5) = {abs(-5)}")
print(f"平方根: math.sqrt({num}) = {math.sqrt(num)}")
print(f"向上取整: math.ceil(3.2) = {math.ceil(3.2)}")
print(f"向下取整: math.floor(3.8) = {math.floor(3.8)}")
