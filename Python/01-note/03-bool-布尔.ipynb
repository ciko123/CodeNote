# %% [markdown]
# ### 布尔值定义

# %%
is_true = True
is_false = False
print(f"布尔值True: {is_true}")
print(f"布尔值False: {is_false}")
print(f"True类型: {type(is_true)}")
print(f"False类型: {type(is_false)}")
# Out:
# 布尔值True: True
# 布尔值False: False
# True类型: <class 'bool'>
# False类型: <class 'bool'>

# %% [markdown]
# ### 比较运算返回布尔值

# %%
x = 10
y = 20

print(x > y)
print(x < y)
print(x == y)
print(x != y)
print(x >= 10)
print(y <= 20)
# Out:
# False
# True
# False
# True
# True
# True

# %%
# 复合条件判断
print(f"\n📝 4. 复合条件判断:")
age = 25
is_student = True
has_job = False

print(f"   年龄: {age}, 是学生: {is_student}, 有工作: {has_job}")
condition1 = age >= 18 and age <= 30
condition2 = is_student or has_job
print(f"   年龄在18-30之间: {condition1}")
print(f"   是学生或有工作: {condition2}")
print(f"   满足所有条件: {condition1 and condition2}")
